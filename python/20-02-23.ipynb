# %% [markdown]
# ### Q1. Explain GET and POST methods.

# %% [markdown]
# >HTTP GET: The Hypertext Transfer Protocol(HTTP) Get method is mainly used at the client (Browser) side to send a request to a specified server to get certain data or resources. Using this method the server should only let us receive the data and not change its state. Hence it is only used to view something and not to change it.
#
# >HTTP POST: The Hypertext Transfer Protocol(HTTP) Post method is mainly used at the client (Browser) side to send data to a Specified server in order to create or rewrite a particular resource/data. This data sent to the server is stored in the request body of the HTTP request.

# %% [markdown]
# _____________

# %% [markdown]
# ### Q2. Why is request used in Flask?

# %% [markdown]
# > resuest is used for extract data which sent from client side.

# %% [markdown]
# ______

# %% [markdown]
# ### Q3. Why is redirect() used in Flask?

# %% [markdown]
# > redirect used with return for different url routing.

# %% [markdown]
# ___________

# %% [markdown]
# ### Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# > templates are html object, in which client send quaries and get result interactively.
#
# > To show specific html file from function.

# %% [markdown]
# ______

# %% [markdown]
# ### Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:5e1523b5-35db-487f-a2f7-456a34886bf9.png)

# %% [markdown]
# _______
